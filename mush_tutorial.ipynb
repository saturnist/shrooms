# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
mushrooms = pd.read_csv("/Users/Saturnist/Google Drive/program/learn_python/mush/mushrooms.csv")
mushrooms
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 8        p         x           y         w       t    p               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# ...

# %%
p_df = mushrooms.loc[mushrooms['class'] == 'p']
p_df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 3        p         x           y         w       t    p               f
# 8        p         x           y         w       t    p               f
# 13       p         x           y         w       t    p               f
# 17       p         x           s         n       t    p               f
# 18       p         x           y         w       t    p               f
# 19       p         x           s         n       t    p               f
# 21       p         x           y         n       t    p               f
# 25       p         f           s         w       t    p               f
# 31       p         x           y         w       t    p               f
# 37       p         x           y         n       t    p               f
# 43       p         x           y         w       t    p               f
# ...

# %%
for column, values in p_df.iteritems():
    print(p_df[column].value_counts())
# Out:
# p    3916
# Name: class, dtype: int64
# x    1708
# f    1556
# k     600
# b      48
# c       4
# Name: cap-shape, dtype: int64
# y    1740
# s    1412
# f     760
# g       4
# Name: cap-surface, dtype: int64
# n    1020
# e     876
# g     808
# y     672
# w     320
# b     120
# p      88
# c      12
# Name: cap-color, dtype: int64
# f    3292
# t     624
# Name: bruises, dtype: int64
# f    2160
# y     576
# s     576
# p     256
# c     192
# n     120
# m      36
# Name: odor, dtype: int64
# f    3898
# a      18
# Name: gill-attachment, dtype: int64
# c    3804
# w     112
# Name: gill-spacing, dtype: int64
# n    2224
# b    1692
# Name: gill-size, dtype: int64
# b    1728
# p     640
# h     528
# g     504
# w     246
# n     112
# k      64
# u      48
# r      24
# y      22
# Name: gill-color, dtype: int64
# t    2016
# e    1900
# Name: stalk-shape, dtype: int64
# b    1856
# ?    1760
# e     256
# c      44
# Name: stalk-root, dtype: int64
# k    2228
# s    1536
# ...

# %%
e_df = mushrooms.loc[mushrooms['class'] == 'e']
e_df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 4        e         x           s         g       f    n               f
# 5        e         x           y         y       t    a               f
# 6        e         b           s         w       t    a               f
# 7        e         b           y         w       t    l               f
# 9        e         b           s         y       t    a               f
# 10       e         x           y         y       t    l               f
# 11       e         x           y         y       t    a               f
# 12       e         b           s         y       t    a               f
# 14       e         x           f         n       f    n               f
# 15       e         s           f         g       f    n               f
# ...

# %%
for column, values in e_df.iteritems():
    print(e_df[column].value_counts())
# Out:
# e    4208
# Name: class, dtype: int64
# x    1948
# f    1596
# b     404
# k     228
# s      32
# Name: cap-shape, dtype: int64
# f    1560
# y    1504
# s    1144
# Name: cap-surface, dtype: int64
# n    1264
# g    1032
# w     720
# e     624
# y     400
# p      56
# b      48
# c      32
# u      16
# r      16
# Name: cap-color, dtype: int64
# t    2752
# f    1456
# Name: bruises, dtype: int64
# n    3408
# l     400
# a     400
# Name: odor, dtype: int64
# f    4016
# a     192
# Name: gill-attachment, dtype: int64
# c    3008
# w    1200
# Name: gill-spacing, dtype: int64
# b    3920
# n     288
# Name: gill-size, dtype: int64
# w    956
# n    936
# p    852
# u    444
# k    344
# g    248
# h    204
# e     96
# y     64
# o     64
# Name: gill-color, dtype: int64
# t    2592
# e    1616
# Name: stalk-shape, dtype: int64
# b    1920
# e     864
# ?     720
# c     512
# r     192
# Name: stalk-root, dtype: int64
# s    3640
# f     408
# k     144
# y      16
# ...

# %%
group_by = mushrooms.groupby(['class', 'cap-color'])
group_by.describe()
# Out:
#                        bruises cap-shape cap-surface gill-attachment  \
# class cap-color
# e     b         count       48        48          48              48
#                 unique       1         3           2               1
#                 top          t         k           y               f
#                 freq        48        16          24              48
#       c         count       32        32          32              32
#                 unique       2         3           3               1
#                 top          f         f           y               f
#                 freq        24        12          16              32
#       e         count      624       624         624             624
#                 unique       1         3           3               1
#                 top          t         x           y               f
#                 freq       624       304         312             624
# ...
